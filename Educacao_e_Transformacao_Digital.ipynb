# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/work/blob/main/Educacao_e_Transformacao_Digital.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Literature review from [Semanticscholar](https://www.semanticscholar.org)
#
# **`keyword`** = 'education digital transformation'

# %% [markdown]
# # É crescente o número de publicações de trabalhos envolvendo **Educação e a Transformação Digital**...

# %% [markdown]
# # A partir de 2020 um grande número desses trabalhos envolvendo **Educação e Transformação Digital** também tem a **Covid** como tema central, mostrando a importância da Transformação Digital em situações disruptivas como a que vivemos com a Pandemia

# %% [markdown]
# # Particularmente a maior parte dos trabalhos envolvem o papel da **Transformação Digital** com foco na **educação Superior, no Aluno e no Aprendizado**.

# %%
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Principais autores de Educação e Transformação Digital
