# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/work/blob/main/IA_N1B_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # **LAB N1B - Controle de Qualidade de Peças de uma Indústria**

# %% [markdown]
# **Pieces** é um data set para o controle de qualidade de peças produzidas por uma indústria. São empregadas quatro medidas (A, B, C e D) para o controle da qualidade das peças. As peças são então *Accept, Refurbish* ou *Reject* segundo o controle de qualidade (atributo `Quality`). A indústria ainda conta com 3 unidades para a produção dessas peças (atributo `Unit`).
#
# Seu trabalho será de criar modelos supervisionados de regressão e classificação. Primeiro você empregará um modelo de regressão linear para predição de medidas das peças. Em seguida você fará uma predição de qualidade das peças a partir de um modelo de classificação.
#
# **Atenção:** Nos modelos não empregue nenhum parâmetro ou funções além do solicitado.

# %% [markdown]
# # Aquisição dos Dados

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_csv('http://meusite.mackenzie.br/rogerio/TIC/pieces3.csv')

# %%
df.head()
# Out:
#     id    A    B    C    D    Quality Unit
# 0  168  5.0  3.5  1.3  0.3     Reject   BH
# 1  527  6.9  3.1  5.4  2.1  Refurbish   BH
# 2  493  6.8  3.0  5.5  2.1  Refurbish   SP
# 3  584  5.9  3.0  5.1  1.8  Refurbish   SP
# 4  534  4.9  NaN  3.3  1.0     Accept   RJ

# %% [markdown]
# # Exercício 1.
#
# Implemente um modelo de regressão linear para estimar o valor da dimensão **`A`** com base em todos os demais atributos, **exceto o `id`**. Em seguida, elimine do modelo os atributos que não são significativos. Para o modelo obtido responda, qual o R2 e o coeficiente do atributo B?

# %%
# seu código

# %% [markdown]
# # Exercício 2.
#
# Com o modelo obtido, qual a predição obtida para as instâncias a seguir?

# %%
#@markdown run to get data
case_a = pd.read_csv('https://github.com/Rogerio-mack/work/raw/main/P1/new_pieces_A.csv')

# %%
case_a
# Out:
#    id    B    C    D    Quality Unit
# 0  34  3.0  5.1  1.8  Refurbish   SP
# 1  98  2.3  4.0  1.3     Accept   RJ

# %%
# seu código

# %% [markdown]
# # Exercício 3
#
# Antes de iniciar, **exclua os valores ausentes** e lembre-se de **não empregar o `id`** como atributo preditor. Implemente os modelos de Classificação
#
# `LogisticRegression(max_iter=1000)`
#
# e
#
# `KNeighborsClassifier(n_neighbors = 20)`
#
# **Apenas com preditores numéricos**. Empregue um conjunto de teste de 30% dos dados, estratificados e random_state = 1. Qual o melhor modelo e sua acuracidade?

# %%
# seu código

# %%
# seu código

# %% [markdown]
# # Exercício 4
#
# Dado o melhor modelo, qual classe apresenta maior percentual de falsos positivos e de falsos negativos?

# %% [markdown]
# # Exercício 5
#
# Dado o melhor modelo, qual a predição e qualidade para os casos a seguir?

# %%
#@markdown run to get data
case_quality = pd.read_csv('https://github.com/Rogerio-mack/work/raw/main/P1/new_pieces_Quality.csv')

# %%
case_quality
# Out:
#     id    A    B    C    D Unit
# 0   78  5.5  2.3  4.0  1.3   RJ
# 1  189  7.2  3.2  6.0  1.8   BH
# 2   18  6.0  2.7  5.1  1.6   SP

# %%
# seu código
