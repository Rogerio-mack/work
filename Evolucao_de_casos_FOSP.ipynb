# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/work/blob/main/Evolucao_de_casos_FOSP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Gathering Data

# %%
# Dados brutos com todos os tipos de câncer no estado de São Paulo
# !gdown 1RZ8MIcQywuZsW_LnGmy60xBAbbhX7CZY --quiet

# %%
df = pd.read_csv('pacigeral_12_23.csv')
display(df.head())
df.shape
# Out:
# <ipython-input-22-f877e1fedebe>:1: DtypeWarning: Columns (23,24,25,32,36,37,73,74,75,78,89,90,91) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('pacigeral_12_23.csv')
#    ESCOLARI  IDADE  SEXO UFNASC UFRESID     IBGE              CIDADE  \
# 0         4     17     2     SP      SP  3538709          PIRACICABA
# 1         9      1     2     SP      SP  3535507  PARAGUACU PAULISTA
# 2         9     18     2     SP      SP  3548500              SANTOS
# 3         5     19     1     RR      SP  3548500              SANTOS
# 4         4     16     1     SP      SP  3548500              SANTOS
#
#    CATEATEND   DTCONSULT  CLINICA  ...  REC03 REC04  IBGEATEN   CIDO  \
# 0          9  2011-06-21       24  ...    NaN   NaN   3538709  80003
# 1          9  2005-02-25        3  ...    NaN   NaN   3506003  80003
# 2          9  2012-05-14       24  ...    NaN   NaN   3548500  80003
# 3          1  2017-08-10       31  ...    NaN   NaN   3548500  80003
# 4          2  2020-04-17       31  ...    NaN   NaN   3548500  80003
#
#              DSCCIDO HABILIT  \
# 0  NEOPLASIA MALIGNA       9
# 1  NEOPLASIA MALIGNA      14
# 2  NEOPLASIA MALIGNA       2
# 3  NEOPLASIA MALIGNA       2
# 4  NEOPLASIA MALIGNA       2
#
#                                              HABIT11 HABILIT1 HABILIT2  \
# 0  UNACON com Serviços de Radioterapia e de Hemat...        1        1
# 1                                            Inativo        6        5
# 2                 UNACON com Serviço de Radioterapia        1        1
# 3                 UNACON com Serviço de Radioterapia        1        1
# 4                 UNACON com Serviço de Radioterapia        1        1
#
#       CIDADEH
# 0  Piracicaba
# 1       Bauru
# 2      Santos
# 3      Santos
# 4      Santos
#
# [5 rows x 100 columns]
# (1178688, 100)

# %%
df.shape
# Out:
# (1178688, 100)

# %%
df.index = pd.to_datetime(df.DTDIAG)

# %%
lista_replace = ['Pele','Mama','Próstata','Pulmão','Colo de Útero','Coloretal','Coloretal','Coloretal','Not Defined','Estômago','Reto','Tiróide']
toplist = list(set(lista_replace))

df['tipo_cancer'] = df['TOPOGRUP'].replace(['C44','C50','C61','C34','C53','C18','C19','C20','C42','C16','C20','C73'],lista_replace)

df.groupby('tipo_cancer').tipo_cancer.count().sort_values(ascending=False).head(10) / len(df)
# Out:
# tipo_cancer
# Pele             0.228854
# Mama             0.136985
# Próstata         0.103433
# Pulmão           0.047110
# Colo de Útero    0.046320
# Coloretal        0.043390
# Not Defined      0.037690
# Estômago         0.036604
# Reto             0.029200
# Tiróide          0.023743
# Name: tipo_cancer, dtype: float64

# %%
plt.figure(figsize=(7,4))

sns.barplot(df.groupby('tipo_cancer').tipo_cancer.count().sort_values(ascending=False).head(10) / len(df))
plt.title('Distribuição de tipos de câncer - Estado de São Paulo\n' + str(df.DTDIAG.min()) + ' a ' + str(df.DTDIAG.max()))

plt.xticks(rotation=45)
plt.show()

# %%
df['cases'] = 1
df_cases = df.resample('M').cases.count()
df_cases_coloretal = df[df['tipo_cancer'] == 'Coloretal'].resample('M').cases.count()

# %%
fig, ax1 = plt.subplots(figsize=(12, 4))

ax1.plot(df_cases, label='Total', color='k', alpha=.8)

ax2 = ax1.twinx()

for tipo in ['Coloretal','Tiróide']:
  ax2.plot(df[df['tipo_cancer'] == tipo].resample('M').cases.count(), label=tipo, alpha=.8)

plt.xlabel('Mês')
plt.ylabel('Casos')
plt.title('Casos por mês - Estado de São Paulo\n' + str(df.DTDIAG.min()) + ' a ' + str(df.DTDIAG.max()))
plt.xticks(rotation=45)
ax1.legend()
ax2.legend()
plt.show()
