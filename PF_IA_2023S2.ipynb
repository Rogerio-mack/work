# %% [markdown]
# <a href="https://colab.research.google.com/github/Rogerio-mack/work/blob/main/PF_IA_2023S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <head>
#   <meta name="author" content="Rogério de Oliveira">
#   <meta institution="author" content="Universidade Presbiteriana Mackenzie">
# </head>
#
# <img src="http://meusite.mackenzie.br/rogerio/mackenzie_logo/UPM.2_horizontal_vermelho.jpg" width=300, align="right">
# <!-- <h1 align=left><font size = 6, style="color:rgb(200,0,0)"> optional title </font></h1> -->

# %% [markdown]
# # Prova Final

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # Orientação para os Exercícios
#
# Complete e execute o seu código e depois responda as questões no corpo do notebook em formato `markdown`. Ao enviar seu notebook envie **apenas células 100% executáveis**.

# %% [markdown]
# # Case: **House Regions**
#
# Neste case você vai empregar dados relacionados a venda de imóveis para estimar a região (**`Regionname`**) com base nos demais atributos.

# %% [markdown]
# # Exercício 1. **Model Selection for Classification** (7,0)
#
#  Faça um modelo de aprendizado de máquina selecionando entre 2 diferentes estimadores de sua escolha. Faça as transformações e operações que forem necessárias nos dados (encodes, normalização, separação de dados de treinamento e teste). Ao final forneça as respostas sobre o seu modelo e faça a predição dos novos casos.

# %%
df = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/house_prices.csv')
df = df[['Rooms', 'Type', 'Price', 'Distance', 'Bedroom2', 'Bathroom', 'Car',
       'Landsize', 'BuildingArea', 'YearBuilt', 'Regionname']]
df = df.dropna().reset_index(drop=True)
df.head()
# Out:
#    Rooms Type      Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      2    h  1035000.0       2.5       2.0       1.0  0.0     156.0
# 1      3    h  1465000.0       2.5       3.0       2.0  0.0     134.0
# 2      4    h  1600000.0       2.5       3.0       1.0  2.0     120.0
# 3      3    h  1876000.0       2.5       4.0       2.0  0.0     245.0
# 4      2    h  1636000.0       2.5       2.0       1.0  2.0     256.0
#
#    BuildingArea  YearBuilt             Regionname
# 0          79.0     1900.0  Northern Metropolitan
# 1         150.0     1900.0  Northern Metropolitan
# 2         142.0     2014.0  Northern Metropolitan
# 3         210.0     1910.0  Northern Metropolitan
# 4         107.0     1890.0  Northern Metropolitan

# %% [markdown]
# #### **Novos casos**

# %%
case = pd.read_csv('https://github.com/Rogerio-mack/IMT_Ciencia_de_Dados/raw/main/data/house_prices_case.csv')
case.head()
# Out:
#    Rooms Type     Price  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 0      3    h  877294.0       9.0       3.0       1.0  2.0     445.0
# 1      4    h  599040.0      33.0       3.0       2.0  2.0    2669.0
#
#    BuildingArea  YearBuilt
# 0         128.0     1964.0
# 1         165.0     1993.0

# %%
# seu código

# %% [markdown]
# ### Q1. Qual o melhor modelo obtido?
#
# Resposta:

# %% [markdown]
# ### Q2. Qual a acuracidade desse modelo?
#
# Resposta:

# %% [markdown]
# ### Q3. Qual classe apresenta maior número de falsos negativos?
#
# Resposta:

# %% [markdown]
# ### Q4. Qual a predição dos novos casos?
#
# Resposta:

# %% [markdown]
# # Exercício 2. **Clustering** (5,0)
#
# Escolha um dos modelos de clusterização (kmédias ou hcluter) e faça uma clusterização sobre as variáveis preditoras do exercício anterior (todos atributos, exceto `Regionname`). Faça as transformações e operações que forem necessárias nos dados (encodes, normalização etc.), verifique o melhor número de clusters a partir da técnica de silhueta e responda as perguntas a seguir.

# %%
# Seu código

# %% [markdown]
# ### Q5. Qual o melhor número de clusters e a silhueta média obtida.
#
# Resposta:

# %% [markdown]
# ### Q6. Qual a quantidade de elementos de cada cluster e quais os clusters dos 6 primeiros elementos?
#
# Resposta:
